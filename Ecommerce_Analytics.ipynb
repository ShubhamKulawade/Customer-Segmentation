# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('E-com_Data.csv')
dataset.head()
# Out:
#    CustomerID Item Code  InvoieNo Date of purchase  Quantity        Time  \
# 0      4355.0     15734  398177.0       29-10-2017       6.0  3:36:00 PM
# 1      4352.0     14616  394422.0       05-10-2017       2.0  2:53:00 PM
# 2      4352.0     14614  394422.0       12-10-2017       2.0  2:53:00 PM
# 3      4352.0    85014B  388633.0       22-08-2017       3.0  2:47:00 PM
# 4      4352.0     15364  394422.0       10-10-2017       2.0  2:53:00 PM
#
#    price per Unit   Price Shipping Location Cancelled_status Reason of return  \
# 0           321.0  1926.0        Location 1              NaN              NaN
# 1           870.0  1740.0        Location 1              NaN              NaN
# 2           933.0  1866.0        Location 1              NaN              NaN
# 3           623.0  1869.0        Location 1              NaN              NaN
# 4           944.0  1888.0        Location 1              NaN              NaN
#
#    Sold as set
# 0          NaN
# 1          NaN
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541116 entries, 0 to 541115
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404189 non-null  float64
#  1   Item Code          537979 non-null  object
#  2   InvoieNo           537979 non-null  float64
#  3   Date of purchase   537979 non-null  object
#  4   Quantity           537979 non-null  float64
#  5   Time               537979 non-null  object
#  6   price per Unit     537979 non-null  float64
#  7   Price              537979 non-null  float64
#  8   Shipping Location  537979 non-null  object
#  9   Cancelled_status   8345 non-null    object
#  10  Reason of return   3 non-null       object
#  11  Sold as set        0 non-null       float64
# dtypes: float64(6), object(6)
# memory usage: 49.5+ MB

# %%
dataset.nunique()
# Out:
# CustomerID            4349
# Item Code             4009
# InvoieNo             24928
# Date of purchase       381
# Quantity               462
# Time                   770
# price per Unit        2900
# Price                13529
# Shipping Location       20
# Cancelled_status         1
# Reason of return         2
# Sold as set              0
# dtype: int64

# %%
print(dataset.isnull().sum()/len(dataset)*100)
# Out:
# CustomerID            25.304556
# Item Code              0.579728
# InvoieNo               0.579728
# Date of purchase       0.579728
# Quantity               0.579728
# Time                   0.579728
# price per Unit         0.579728
# Price                  0.579728
# Shipping Location      0.579728
# Cancelled_status      98.457817
# Reason of return      99.999446
# Sold as set          100.000000
# dtype: float64

# %%
dataset.duplicated().sum()
# Out:
# 3145

# %%
dataset = dataset.rename(columns = {'InvoieNo' : 'InvoiceNo',
                                   'Date of purchase' : 'Date'})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541116 entries, 0 to 541115
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404189 non-null  float64
#  1   Item Code          537979 non-null  object
#  2   InvoiceNo          537979 non-null  float64
#  3   Date               537979 non-null  object
#  4   Quantity           537979 non-null  float64
#  5   Time               537979 non-null  object
#  6   price per Unit     537979 non-null  float64
#  7   Price              537979 non-null  float64
#  8   Shipping Location  537979 non-null  object
#  9   Cancelled_status   8345 non-null    object
#  10  Reason of return   3 non-null       object
#  11  Sold as set        0 non-null       float64
# dtypes: float64(6), object(6)
# memory usage: 49.5+ MB

# %%
dataset = dataset.drop_duplicates(ignore_index = True)

# %%
print(dataset.isnull().sum())
# Out:
# CustomerID           133790
# Item Code                 1
# InvoiceNo                 1
# Date                      1
# Quantity                  1
# Time                      1
# price per Unit            1
# Price                     1
# Shipping Location         1
# Cancelled_status     529626
# Reason of return     537968
# Sold as set          537971
# dtype: int64

# %%
# dropping missing customerid
dataset = dataset.dropna(subset=['CustomerID'])

# %%
dataset.isnull().sum()
# Out:
# CustomerID                0
# Item Code                 0
# InvoiceNo                 0
# Date                      0
# Quantity                  0
# Time                      0
# price per Unit            0
# Price                     0
# Shipping Location         0
# Cancelled_status     395998
# Reason of return     404181
# Sold as set          404181
# dtype: int64

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset.head()
# Out:
#    CustomerID Item Code  InvoiceNo       Date  Quantity        Time  \
# 0      4355.0     15734   398177.0 2017-10-29       6.0  3:36:00 PM
# 1      4352.0     14616   394422.0 2017-05-10       2.0  2:53:00 PM
# 2      4352.0     14614   394422.0 2017-12-10       2.0  2:53:00 PM
# 3      4352.0    85014B   388633.0 2017-08-22       3.0  2:47:00 PM
# 4      4352.0     15364   394422.0 2017-10-10       2.0  2:53:00 PM
#
#    price per Unit   Price Shipping Location Cancelled_status Reason of return  \
# 0           321.0  1926.0        Location 1              NaN              NaN
# 1           870.0  1740.0        Location 1              NaN              NaN
# 2           933.0  1866.0        Location 1              NaN              NaN
# 3           623.0  1869.0        Location 1              NaN              NaN
# 4           944.0  1888.0        Location 1              NaN              NaN
#
#    Sold as set
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %%
#creating one more data column
dataset['Date1'] = dataset['Date']

# %%
dataset.head()
# Out:
#    CustomerID Item Code  InvoiceNo       Date  Quantity        Time  \
# 0      4355.0     15734   398177.0 2017-10-29       6.0  3:36:00 PM
# 1      4352.0     14616   394422.0 2017-05-10       2.0  2:53:00 PM
# 2      4352.0     14614   394422.0 2017-12-10       2.0  2:53:00 PM
# 3      4352.0    85014B   388633.0 2017-08-22       3.0  2:47:00 PM
# 4      4352.0     15364   394422.0 2017-10-10       2.0  2:53:00 PM
#
#    price per Unit   Price Shipping Location Cancelled_status Reason of return  \
# 0           321.0  1926.0        Location 1              NaN              NaN
# 1           870.0  1740.0        Location 1              NaN              NaN
# 2           933.0  1866.0        Location 1              NaN              NaN
# 3           623.0  1869.0        Location 1              NaN              NaN
# 4           944.0  1888.0        Location 1              NaN              NaN
#
#    Sold as set      Date1
# 0          NaN 2017-10-29
# 1          NaN 2017-05-10
# ...

# %%
dataset['Date1'].describe()
# Out:
# count                  404181
# unique                    381
# top       2017-11-24 00:00:00
# freq                     2522
# first     2016-02-12 00:00:00
# last      2017-12-19 00:00:00
# Name: Date1, dtype: object

# %%
# Recency = Latest date - Last invoice date
# Frequency = count of invoiceno of transactions done by customer
# Monetary = sum of total spend by the customer (or earned from customer)

# %%
import datetime as dt
latest_date = dt.datetime(2017,12,20)

# %%
RFMScores = dataset.groupby('CustomerID').agg({'Date1':
                                              lambda x:(latest_date - x.max()).days,
                                              'Date' : lambda x : x.nunique(),
                                              'Price' : lambda x : x.sum()})

#Converting invocie date into int
RFMScores['Date'] = RFMScores['Date'].astype(int)


# Renaming columns as Recency, Frequency, Monetary
RFMScores.rename(columns={'Date1': 'Recency', 'Date': 'Frequency',
                         'Price':'Monetary'}, inplace=True)

RFMScores.reset_index().head(10)
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0         2.0        4         63  553704.0
# 1         3.0       77         18  257404.0
# 2         4.0       20         10  176613.0
# 3         5.0       18          7   41976.0
# 4         6.0        9         42  151822.0
# 5         7.0      208          4    9410.0
# 6         8.0      234         10  135550.0
# 7         9.0       15          7   65832.0
# 8        10.0       16         22  331601.0
# 9        11.0        9         10  771439.0

# %%
RFMScores.Recency.describe()
# Out:
# count    4349.000000
# mean       61.445160
# std        89.656941
# min         1.000000
# 25%        10.000000
# 50%        19.000000
# 75%        73.000000
# max       617.000000
# Name: Recency, dtype: float64

# %%
x = RFMScores['Recency']
bx = sns.distplot(x)

# %%
RFMScores.Frequency.describe()
# Out:
# count    4349.000000
# mean       27.396643
# std        33.594882
# min         1.000000
# 25%         9.000000
# 50%        16.000000
# 75%        33.000000
# max       378.000000
# Name: Frequency, dtype: float64

# %%
RFMScores.Monetary.describe()
# Out:
# count    4.349000e+03
# mean     2.299380e+05
# std      8.572589e+05
# min     -5.037200e+04
# 25%      3.814800e+04
# 50%      8.365500e+04
# 75%      2.056120e+05
# max      3.553619e+07
# Name: Monetary, dtype: float64

# %%
quant = RFMScores.quantile(q=[0.25, 0.50, 0.75])
quant = quant.to_dict()

# %%
quant
# Out:
# {'Recency': {0.25: 10.0, 0.5: 19.0, 0.75: 73.0},
#  'Frequency': {0.25: 9.0, 0.5: 16.0, 0.75: 33.0},
#  'Monetary': {0.25: 38148.0, 0.5: 83655.0, 0.75: 205612.0}}

# %%
# Function to create R, F and M segments

def RScores(x,p,d):
    if x<=d[p][0.25]:
        return 1
    elif x<=d[p][0.50]:
        return 2
    elif x<=d[p][0.75]:
        return 3
    else:
        return 4
    
    
    
def FScores(x,p,d):
    if x<=d[p][0.25]:
        return 4
    elif x<=d[p][0.50]:
        return 3
    elif x<=d[p][0.75]:
        return 2
    else:
        return 1

# %%
RFMScores['R'] = RFMScores['Recency'].apply(RScores, args=('Recency', quant))
RFMScores['F'] = RFMScores['Frequency'].apply(FScores, args=('Frequency', quant))
RFMScores['M'] = RFMScores['Monetary'].apply(FScores, args=('Monetary', quant))
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M
# CustomerID
# 2.0               4         63  553704.0  1  1  1
# 3.0              77         18  257404.0  4  2  1
# 4.0              20         10  176613.0  3  3  2
# 5.0              18          7   41976.0  2  4  3
# 6.0               9         42  151822.0  1  1  2

# %%
RFMScores['RFMScore'] = RFMScores[['R', 'F', 'M']].sum(axis = 1)
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M  RFMScore
# CustomerID
# 2.0               4         63  553704.0  1  1  1         3
# 3.0              77         18  257404.0  4  2  1         7
# 4.0              20         10  176613.0  3  3  2         8
# 5.0              18          7   41976.0  2  4  3         9
# 6.0               9         42  151822.0  1  1  2         4

# %%
Loyalty_level = ['Platinum','Gold','Silver','Bronze']
Score_cuts = pd.qcut(RFMScores.RFMScore, q=4, labels=Loyalty_level)
RFMScores['RFM_Loyalty_Level'] = Score_cuts.values
RFMScores.reset_index().head(12)
# Out:
#     CustomerID  Recency  Frequency  Monetary  R  F  M  RFMScore  \
# 0          2.0        4         63  553704.0  1  1  1         3
# 1          3.0       77         18  257404.0  4  2  1         7
# 2          4.0       20         10  176613.0  3  3  2         8
# 3          5.0       18          7   41976.0  2  4  3         9
# 4          6.0        9         42  151822.0  1  1  2         4
# 5          7.0      208          4    9410.0  4  4  4        12
# 6          8.0      234         10  135550.0  4  3  2         9
# 7          9.0       15          7   65832.0  2  4  3         9
# 8         10.0       16         22  331601.0  2  2  1         5
# 9         11.0        9         10  771439.0  1  3  1         5
# 10        12.0        2         11  105674.0  1  3  2         6
# 11        13.0       14         42  705406.0  2  1  1         4
#
#    RFM_Loyalty_Level
# 0           Platinum
# 1               Gold
# 2               Gold
# 3             Silver
# ...

# %%
RFMScores['RFMGroup'] = RFMScores.R.map(str)+RFMScores.F.map(str)+RFMScores.M.map(str)
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M  RFMScore RFM_Loyalty_Level  \
# CustomerID
# 2.0               4         63  553704.0  1  1  1         3          Platinum
# 3.0              77         18  257404.0  4  2  1         7              Gold
# 4.0              20         10  176613.0  3  3  2         8              Gold
# 5.0              18          7   41976.0  2  4  3         9            Silver
# 6.0               9         42  151822.0  1  1  2         4          Platinum
#
#            RFMGroup
# CustomerID
# 2.0             111
# 3.0             421
# 4.0             332
# 5.0             243
# 6.0             112

# %%
RFMScores[RFMScores['RFMGroup']=='111'].sort_values('Monetary', ascending=False).reset_index().head(15)
# Out:
#     CustomerID  Recency  Frequency    Monetary  R  F  M  RFMScore  \
# 0       1704.0        3        235  35536194.0  1  1  1         3
# 1       1896.0        2        356  17743855.0  1  1  1         3
# 2         56.0       10        108  14357682.0  1  1  1         3
# 3       1346.0        9        237  12647317.0  1  1  1         3
# 4       3802.0        3        236  12319439.0  1  1  1         3
# 5       4234.0        3         94  10654918.0  1  1  1         3
# 6       1006.0        5        211   9351019.0  1  1  1         3
# 7       3203.0        5         99   8102167.0  1  1  1         3
# 8       2193.0        1        357   7966054.0  1  1  1         3
# 9       1448.0        5        190   7892625.0  1  1  1         3
# 10      3759.0        9        112   7545149.0  1  1  1         3
# 11       569.0        5        327   7408035.0  1  1  1         3
# 12      1301.0        5        105   6146204.0  1  1  1         3
# ...

# %%
new_data = RFMScores.iloc[:,0:3]
new_data.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 2.0               4         63  553704.0
# 3.0              77         18  257404.0
# 4.0              20         10  176613.0
# 5.0              18          7   41976.0
# 6.0               9         42  151822.0

# %% [markdown]
# KMEANS CLUSTERING

# %%
from sklearn.cluster import KMeans

sum_of_sq_dist = {}

for k in range(1,20):
    km = KMeans(n_clusters=k, init='k-means++', max_iter=500)
    km = km.fit(new_data)
    sum_of_sq_dist[k] = km.inertia_
    
sns.pointplot(x= list(sum_of_sq_dist.keys()), y = list(sum_of_sq_dist.values()))
plt.xlabel("No of Cluster(k)")
plt.ylabel("Sum of Square Distance")
plt.title("Elbow Method for Optimal K Value")
plt.show()

# %%
kmeans_cluster = KMeans( n_clusters=6, init='k-means++', max_iter=500)
kmeans_cluster.fit(new_data)
# Out:
# KMeans(max_iter=500, n_clusters=6)

# %%
RFMScores['Cluster'] = kmeans_cluster.labels_
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M  RFMScore RFM_Loyalty_Level  \
# CustomerID
# 2.0               4         63  553704.0  1  1  1         3          Platinum
# 3.0              77         18  257404.0  4  2  1         7              Gold
# 4.0              20         10  176613.0  3  3  2         8              Gold
# 5.0              18          7   41976.0  2  4  3         9            Silver
# 6.0               9         42  151822.0  1  1  2         4          Platinum
#
#            RFMGroup  Cluster
# CustomerID
# 2.0             111        5
# 3.0             421        0
# 4.0             332        0
# 5.0             243        0
# 6.0             112        0

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shubham'

# %%
RFMScores.to_csv('new_cluster_data.csv')
